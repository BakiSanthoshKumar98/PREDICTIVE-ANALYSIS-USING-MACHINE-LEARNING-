# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/harin.HARIHARSHU/Desktop/sampath sir python projects/Supervised  and UnSupervised Datasets/Datasets_All/Regression/taxi_trip_pricing.csv")

# %%
df
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# ...

# %%
df.dtypes
# Out:
# Trip_Distance_km         float64
# Time_of_Day               object
# Day_of_Week               object
# Passenger_Count          float64
# Traffic_Conditions        object
# Weather                   object
# Base_Fare                float64
# Per_Km_Rate              float64
# Per_Minute_Rate          float64
# Trip_Duration_Minutes    float64
# Trip_Price               float64
# dtype: object

# %%
category_list=['Time_of_Day','Day_of_Week','Traffic_Conditions','Weather']

# %%
category_list
# Out:
# ['Time_of_Day', 'Day_of_Week', 'Traffic_Conditions', 'Weather']

# %%
for i in category_list:
        df[i] = df[i].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Trip_Distance_km       950 non-null    float64
#  1   Time_of_Day            950 non-null    category
#  2   Day_of_Week            950 non-null    category
#  3   Passenger_Count        950 non-null    float64
#  4   Traffic_Conditions     950 non-null    category
#  5   Weather                950 non-null    category
#  6   Base_Fare              950 non-null    float64
#  7   Per_Km_Rate            950 non-null    float64
#  8   Per_Minute_Rate        950 non-null    float64
#  9   Trip_Duration_Minutes  950 non-null    float64
#  10  Trip_Price             951 non-null    float64
# dtypes: category(4), float64(7)
# memory usage: 59.3 KB

# %%
df.isnull().sum()
# Out:
# Trip_Distance_km         50
# Time_of_Day              50
# Day_of_Week              50
# Passenger_Count          50
# Traffic_Conditions       50
# Weather                  50
# Base_Fare                50
# Per_Km_Rate              50
# Per_Minute_Rate          50
# Trip_Duration_Minutes    50
# Trip_Price               49
# dtype: int64

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0               19.35     Morning     Weekday              3.0
# 1               47.59   Afternoon     Weekday              1.0
# 2               36.87     Evening     Weekend              1.0
# 3               30.33     Evening     Weekday              4.0
# 4                 NaN     Evening     Weekday              3.0
# ..                ...         ...         ...              ...
# 995              5.49   Afternoon     Weekend              4.0
# 996             45.95       Night     Weekday              4.0
# 997              7.70     Morning     Weekday              3.0
# 998             47.56     Morning     Weekday              1.0
# 999             22.85     Morning     Weekend              3.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 0                  Low   Clear       3.56         0.80             0.32
# ...

# %%
df.sample()
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 63             18.48   Afternoon     Weekday              4.0
#
#    Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 63             Medium   Clear       2.84         1.37             0.39
#
#     Trip_Duration_Minutes  Trip_Price
# 63                 106.41     69.6575

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
df['Trip_Distance_km'].hist()
plt.title('Trip Distance Distribution')
plt.xlabel('Distance (km)')
plt.ylabel('Frequency')
plt.show()

# %%
# 1. Distribution of Continuous Variables
continuous_cols = ['Trip_Distance_km', 'Trip_Duration_Minutes', 'Trip_Price']

for col in continuous_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30, color='blue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
# 2. Count Plot for Categorical Variables
categorical_cols = ['Time_of_Day', 'Day_of_Week', 'Traffic_Conditions', 'Weather']

for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df, x=col, palette='Set2')
    plt.title(f'Count of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\2225875954.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\2225875954.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\2225875954.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=col, palette='Set2')
# ...

# %%
sns.boxplot(x=df['Trip_Price'])
plt.title('Trip Price Box Plot')
plt.ylabel('Price')
plt.show()

# %%
# 1. Scatter Plot for Continuous Variables
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Trip_Distance_km', y='Trip_Price', hue='Traffic_Conditions')
plt.title('Trip Distance vs Trip Price')
plt.xlabel('Trip Distance (km)')
plt.ylabel('Trip Price')
plt.legend(title='Traffic Conditions')
plt.show()

# %%
# 2. Box Plot for Categorical vs Continuous Variables
for col in categorical_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=df, x=col, y='Trip_Price', palette='Set3')
    plt.title(f'Trip Price vs {col}')
    plt.xlabel(col)
    plt.ylabel('Trip Price')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3058428155.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='Trip_Price', palette='Set3')
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3058428155.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='Trip_Price', palette='Set3')
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3058428155.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='Trip_Price', palette='Set3')
# ...

# %%
df.sample()
# Out:
#      Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 139             48.62   Afternoon     Weekend              1.0
#
#     Traffic_Conditions Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  \
# 139                Low    Rain       2.15         1.17             0.11
#
#      Trip_Duration_Minutes  Trip_Price
# 139                  74.49     67.2293

# %%
df.plot.line(x='Trip_Distance_km', y='Trip_Price')
plt.title('Trip Duration vs Trip Price')
plt.xlabel('Duration (minutes)')
plt.ylabel('Price')
plt.show()

# %%
df['Traffic_Conditions'].value_counts().plot.bar()
plt.title('Traffic Conditions Distribution')
plt.xlabel('Traffic Conditions')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Violin Plot for Continuous Variable across Multiple Categorical Variables
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x='Traffic_Conditions', y='Trip_Price', hue='Weather', split=True, palette='pastel')
plt.title('Trip Price by Traffic Conditions and Weather')
plt.xlabel('Traffic Conditions')
plt.ylabel('Trip Price')
plt.show()

# %%
# 1. Boxplot for Outliers in Continuous Variables
for col in continuous_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=df, x=col, palette='Set1')
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.show()
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\2036556522.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, palette='Set1')
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\2036556522.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, palette='Set1')
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\2036556522.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, palette='Set1')

# %%
# 2. Pie Chart for Proportions in Categorical Variables
for col in categorical_cols:
    plt.figure(figsize=(6, 6))
    df[col].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colormap='Set3')
    plt.title(f'Proportion of {col}')
    plt.ylabel('')  # Hide y-axis label
    plt.show()

# %%
# 1. KDE Plot for Continuous Variables
plt.figure(figsize=(10, 6))
for col in continuous_cols:
    sns.kdeplot(df[col], label=col, fill=True)
plt.title('KDE Plot of Continuous Variables')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
# 3. Heatmap for Traffic Conditions and Time of Day
traffic_time_pivot = df.pivot_table(index='Traffic_Conditions', columns='Time_of_Day', values='Trip_Price', aggfunc='mean')
plt.figure(figsize=(8, 6))
sns.heatmap(traffic_time_pivot, annot=True, cmap='YlGnBu', fmt=".2f")
plt.title('Average Trip Price (Traffic vs Time of Day)')
plt.show()
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3445228593.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   traffic_time_pivot = df.pivot_table(index='Traffic_Conditions', columns='Time_of_Day', values='Trip_Price', aggfunc='mean')

# %%
# 1. 3D Scatter Plot for Trip Distance, Duration, and Price
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(
    df['Trip_Distance_km'], df['Trip_Duration_Minutes'], df['Trip_Price'],
    c=df['Traffic_Conditions'].factorize()[0], cmap='viridis'
)
ax.set_xlabel('Trip Distance (km)')
ax.set_ylabel('Trip Duration (min)')
ax.set_zlabel('Trip Price')
plt.title('3D Scatter: Distance vs Duration vs Price')
plt.legend(*scatter.legend_elements(), title="Traffic")
plt.show()

# %%
# 1. Pairplot for Continuous Variables with Hue
sns.pairplot(df, vars=continuous_cols, hue='Time_of_Day', palette='husl')
plt.suptitle('Pairplot of Continuous Variables with Time of Day', y=1.02)
plt.show()

# %%
# 2. Joint Plot for Duration and Price
sns.jointplot(
    data=df, x='Trip_Duration_Minutes', y='Trip_Price', kind='hex', cmap='coolwarm'
)
plt.suptitle('Hexbin Plot: Duration vs Price', y=1.02)
plt.show()

# %%
# 2. Swarm Plot for Price Across Time and Traffic Conditions
plt.figure(figsize=(12, 6))
sns.swarmplot(data=df, x='Time_of_Day', y='Trip_Price', hue='Traffic_Conditions', palette='Set2')
plt.title('Trip Price by Time of Day and Traffic Conditions')
plt.xlabel('Time of Day')
plt.ylabel('Trip Price')
plt.legend(title='Traffic Conditions')
plt.show()
# Out:
# C:\Users\harin.HARIHARSHU\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# 3. Radar Chart for Summary of Continuous Variables
from math import pi

# Summarize continuous variables
summary = df[continuous_cols].mean()

# Prepare data for radar chart
categories = list(summary.index)
values = summary.values.flatten().tolist()
values += values[:1]  # Close the radar chart loop

# Radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

ax.plot(angles, values, linewidth=2, linestyle='solid', label='Average')
ax.fill(angles, values, alpha=0.4)
ax.set_xticks(angles[:-1])
ax.set_xticklabels(categories)
plt.title('Radar Chart of Continuous Variables')
plt.legend(loc='upper right')
plt.show()

# %%
df.isna().sum()
# Out:
# Trip_Distance_km         50
# Time_of_Day              50
# Day_of_Week              50
# Passenger_Count          50
# Traffic_Conditions       50
# Weather                  50
# Base_Fare                50
# Per_Km_Rate              50
# Per_Minute_Rate          50
# Trip_Duration_Minutes    50
# Trip_Price               49
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Trip_Distance_km       950 non-null    float64
#  1   Time_of_Day            950 non-null    category
#  2   Day_of_Week            950 non-null    category
#  3   Passenger_Count        950 non-null    float64
#  4   Traffic_Conditions     950 non-null    category
#  5   Weather                950 non-null    category
#  6   Base_Fare              950 non-null    float64
#  7   Per_Km_Rate            950 non-null    float64
#  8   Per_Minute_Rate        950 non-null    float64
#  9   Trip_Duration_Minutes  950 non-null    float64
#  10  Trip_Price             951 non-null    float64
# dtypes: category(4), float64(7)
# memory usage: 59.3 KB

# %%
df.drop(['Day_of_Week'], axis=1, inplace=True)

# %%
df['Trip_Distance_km'].fillna(df['Trip_Distance_km'].mean(), inplace=True)
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3639037552.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Trip_Distance_km'].fillna(df['Trip_Distance_km'].mean(), inplace=True)

# %%
df['Trip_Price'].fillna(df['Trip_Price'].median(), inplace=True)
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3411356423.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Trip_Price'].fillna(df['Trip_Price'].median(), inplace=True)

# %%
df['Weather'].fillna(df['Weather'].mode()[0], inplace=True)
df['Time_of_Day'].fillna(df['Time_of_Day'].mode()[0], inplace=True)
df['Traffic_Conditions'].fillna(df['Traffic_Conditions'].mode()[0], inplace=True)
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\1424597331.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weather'].fillna(df['Weather'].mode()[0], inplace=True)
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\1424597331.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['Passenger_Count'].fillna(df['Passenger_Count'].median(), inplace=True)
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3486715895.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Passenger_Count'].fillna(df['Passenger_Count'].median(), inplace=True)

# %%
df.isna().sum()
# Out:
# Trip_Distance_km          0
# Time_of_Day               0
# Passenger_Count           0
# Traffic_Conditions        0
# Weather                   0
# Base_Fare                50
# Per_Km_Rate              50
# Per_Minute_Rate          50
# Trip_Duration_Minutes    50
# Trip_Price                0
# dtype: int64

# %%
# For numerical columns
numerical_cols = ['Base_Fare', 'Per_Km_Rate', 'Per_Minute_Rate', 'Trip_Duration_Minutes']
for col in numerical_cols:
    df[col].fillna(df[col].mean(), inplace=True)
# Out:
# C:\Users\harin.HARIHARSHU\AppData\Local\Temp\ipykernel_18280\3139136455.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# Trip_Distance_km         0
# Time_of_Day              0
# Passenger_Count          0
# Traffic_Conditions       0
# Weather                  0
# Base_Fare                0
# Per_Km_Rate              0
# Per_Minute_Rate          0
# Trip_Duration_Minutes    0
# Trip_Price               0
# dtype: int64

# %%
df.describe()
# Out:
#        Trip_Distance_km  Passenger_Count    Base_Fare  Per_Km_Rate  \
# count       1000.000000      1000.000000  1000.000000  1000.000000
# mean          27.070547         2.453000     3.502989     1.233316
# std           19.400775         1.079331     0.848107     0.418922
# min            1.230000         1.000000     2.010000     0.500000
# 25%           13.107500         2.000000     2.770000     0.870000
# 50%           26.995000         2.000000     3.502989     1.233316
# 75%           37.782500         3.000000     4.202500     1.580000
# max          146.067047         4.000000     5.000000     2.000000
#
#        Per_Minute_Rate  Trip_Duration_Minutes   Trip_Price
# count      1000.000000            1000.000000  1000.000000
# mean          0.292916              62.118116    56.541560
# std           0.112662              31.339413    39.492129
# min           0.100000               5.010000     6.126900
# 25%           0.197500              37.107500    34.578850
# ...

# %%
import numpy as np

# Define the column for which you want to handle outliers
column_name = 'Trip_Distance_km'

# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df[column_name].quantile(0.25)
Q3 = df[column_name].quantile(0.75)

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df[column_name] < lower_bound) | (df[column_name] > upper_bound)]
print(f"Number of outliers in '{column_name}': {len(outliers)}")

# Option 1: Remove outliers
df_no_outliers = df[(df[column_name] >= lower_bound) & (df[column_name] <= upper_bound)]
print(f"Data shape after removing outliers: {df_no_outliers.shape}")

# Option 2: Cap outliers at the lower and upper bounds
df_capped = df.copy()
df_capped[column_name] = np.where(df[column_name] < lower_bound, lower_bound,
                                  np.where(df[column_name] > upper_bound, upper_bound, df[column_name]))

print(f"Outliers capped for column: '{column_name}'")
# Out:
# Number of outliers in 'Trip_Distance_km': 20
# Data shape after removing outliers: (980, 10)
# Outliers capped for column: 'Trip_Distance_km'

# %%
numerical_columns = ['Base_Fare', 'Per_Km_Rate', 'Per_Minute_Rate', 'Trip_Duration_Minutes', 'Trip_Distance_km', 'Trip_Price']

for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Cap outliers
    df[col] = np.where(df[col] < lower_bound, lower_bound,
                       np.where(df[col] > upper_bound, upper_bound, df[col]))

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Encoding

# %%
df
# Out:
#      Trip_Distance_km Time_of_Day  Passenger_Count Traffic_Conditions Weather  \
# 0           19.350000     Morning              3.0                Low   Clear
# 1           47.590000   Afternoon              1.0               High   Clear
# 2           36.870000     Evening              1.0               High   Clear
# 3           30.330000     Evening              4.0                Low   Clear
# 4           27.070547     Evening              3.0               High   Clear
# ..                ...         ...              ...                ...     ...
# 995          5.490000   Afternoon              4.0             Medium   Clear
# 996         45.950000       Night              4.0             Medium   Clear
# 997          7.700000     Morning              3.0                Low    Rain
# 998         47.560000     Morning              1.0                Low   Clear
# 999         22.850000     Morning              3.0             Medium   Clear
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding
label_encoder = LabelEncoder()
df['Traffic_Conditions'] = label_encoder.fit_transform(df['Traffic_Conditions'])

# %%
df
# Out:
#      Trip_Distance_km Time_of_Day  Passenger_Count  Traffic_Conditions  \
# 0           19.350000     Morning              3.0                   1
# 1           47.590000   Afternoon              1.0                   0
# 2           36.870000     Evening              1.0                   0
# 3           30.330000     Evening              4.0                   1
# 4           27.070547     Evening              3.0                   0
# ..                ...         ...              ...                 ...
# 995          5.490000   Afternoon              4.0                   2
# 996         45.950000       Night              4.0                   2
# 997          7.700000     Morning              3.0                   1
# 998         47.560000     Morning              1.0                   1
# 999         22.850000     Morning              3.0                   2
#
#     Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes  \
# ...

# %%
df['Time_of_Day'].value_counts()
# Out:
# Time_of_Day
# Afternoon    421
# Morning      283
# Evening      203
# Night         93
# Name: count, dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Clear    717
# Rain     227
# Snow      56
# Name: count, dtype: int64

# %%
df
# Out:
#      Trip_Distance_km Time_of_Day  Passenger_Count  Traffic_Conditions  \
# 0           19.350000     Morning              3.0                   1
# 1           47.590000   Afternoon              1.0                   0
# 2           36.870000     Evening              1.0                   0
# 3           30.330000     Evening              4.0                   1
# 4           27.070547     Evening              3.0                   0
# ..                ...         ...              ...                 ...
# 995          5.490000   Afternoon              4.0                   2
# 996         45.950000       Night              4.0                   2
# 997          7.700000     Morning              3.0                   1
# 998         47.560000     Morning              1.0                   1
# 999         22.850000     Morning              3.0                   2
#
#     Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Time_of_Day'] = label_encoder.fit_transform(df['Time_of_Day'])

# %%
df
# Out:
#      Trip_Distance_km  Time_of_Day  Passenger_Count  Traffic_Conditions  \
# 0           19.350000            2              3.0                   1
# 1           47.590000            0              1.0                   0
# 2           36.870000            1              1.0                   0
# 3           30.330000            1              4.0                   1
# 4           27.070547            1              3.0                   0
# ..                ...          ...              ...                 ...
# 995          5.490000            0              4.0                   2
# 996         45.950000            3              4.0                   2
# 997          7.700000            2              3.0                   1
# 998         47.560000            2              1.0                   1
# 999         22.850000            2              3.0                   2
#
#     Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['Weather'] = label_encoder.fit_transform(df['Weather'])

# %%
df
# Out:
#      Trip_Distance_km  Time_of_Day  Passenger_Count  Traffic_Conditions  \
# 0           19.350000            2              3.0                   1
# 1           47.590000            0              1.0                   0
# 2           36.870000            1              1.0                   0
# 3           30.330000            1              4.0                   1
# 4           27.070547            1              3.0                   0
# ..                ...          ...              ...                 ...
# 995          5.490000            0              4.0                   2
# 996         45.950000            3              4.0                   2
# 997          7.700000            2              3.0                   1
# 998         47.560000            2              1.0                   1
# 999         22.850000            2              3.0                   2
#
#      Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes  \
# ...

# %%
x=df.drop(['Trip_Price'],axis=1)  # Features

# %%
y=df['Trip_Price'] #Target

# %%
df['Trip_Price'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      36.2624
# 1      50.0745
# 2      52.9032
# 3      36.4698
# 4      15.6180
#         ...
# 995    34.4049
# 996    62.1295
# 997    33.1236
# 998    61.2090
# 999    45.4437
# Name: Trip_Price, Length: 1000, dtype: float64>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
scaler=StandardScaler()
x_train["Trip_Duration_Minutes"]=scaler.fit_transform(x_train[["Trip_Duration_Minutes"]])
x_test["Trip_Duration_Minutes"]=scaler.transform(x_test[["Trip_Duration_Minutes"]])

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
scaler=StandardScaler()
x_train["Trip_Distance_km"]=scaler.fit_transform(x_train[["Trip_Distance_km"]])
x_test["Trip_Distance_km"]=scaler.transform(x_test[["Trip_Distance_km"]])

# %%
x_train
# Out:
#      Trip_Distance_km  Time_of_Day  Passenger_Count  Traffic_Conditions  \
# 29          -1.476838            1              2.0                   2
# 535          1.315944            2              1.0                   0
# 695          0.277138            2              4.0                   1
# 557         -1.532046            0              2.0                   1
# 836          1.223295            2              3.0                   2
# ..                ...          ...              ...                 ...
# 106         -0.345384            0              4.0                   0
# 270          0.895218            0              2.0                   2
# 860          0.789878            1              1.0                   1
# 435          0.558257            2              1.0                   2
# 102         -0.644270            1              1.0                   1
#
#      Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes
# ...

# %%
x_test
# Out:
#      Trip_Distance_km  Time_of_Day  Passenger_Count  Traffic_Conditions  \
# 521         -0.437398            3              2.0                   1
# 737          0.917428            2              1.0                   2
# 740         -0.182932            1              1.0                   2
# 660         -0.514182            0              4.0                   2
# 411          1.332443            2              4.0                   1
# ..                ...          ...              ...                 ...
# 408          1.193470            0              2.0                   2
# 332         -1.576467            2              4.0                   0
# 208         -1.605658            0              3.0                   1
# 613         -1.367056            0              4.0                   1
# 78          -0.507201            2              1.0                   2
#
#      Weather  Base_Fare  Per_Km_Rate  Per_Minute_Rate  Trip_Duration_Minutes
# ...

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
# Out:
# 0.8574236996134017
